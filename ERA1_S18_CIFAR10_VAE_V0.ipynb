# %%
# !nvidia-smi
# Out:
# Thu Sep 21 07:48:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -q albumentations==1.0.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 3.1 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import numpy as np
import cv2
import PIL
import math
from PIL import Image as img
from tqdm import tqdm
from tqdm.notebook import trange, tqdm
import matplotlib.pyplot as plt
import albumentations as A
cuda = torch.cuda.is_available()
import datetime
import seaborn as sns
from pathlib import Path
from torchsummary import summary
sns.set()
from tqdm.auto import tqdm
from torchvision.utils import save_image

# %%
class Albumentations_transform:
  """
  Class to create test and train transforms using Albumentations. ToTensor() will be appended at the end of transforms list
  """
  def __init__(self, transforms_list=[]):
      self.transforms = A.Compose(transforms_list)

  """
  Library works only with named arguments and numpy array. Hence to make it compatible with torchvision, using wrapper to convert to np array
  """
  def __call__(self, img):
      img = np.array(img)
      img = self.transforms(image=img)['image']  # if ['image'] is not given, then it will give key error in dataloader
      img = np.transpose(img, (2,0,1))
      return img

# %%
if cuda:
    torch.cuda.manual_seed(1)

dataloader_args = dict(shuffle=True, batch_size=512, num_workers=2, pin_memory=True) if cuda else dict(shuffle=True, batch_size=64)

channels_mean  = [0.49139968, 0.48215841, 0.44653091]
channels_stdev = [0.24703223, 0.24348513, 0.26158784]


test_transforms   = Albumentations_transform([A.Normalize(mean=channels_mean, std=channels_stdev),])
train_transforms  = Albumentations_transform([A.Normalize(mean=channels_mean, std=channels_stdev),
                                              A.Sequential([A.PadIfNeeded(min_height=40, min_width=40, border_mode=cv2.BORDER_CONSTANT, value=(0.49139968, 0.48215841, 0.44653091)),
                                                            A.RandomCrop(32, 32)], p=1.0),
                                              A.HorizontalFlip(),
                                              A.Cutout(num_holes=1, max_h_size=16, max_w_size=16, fill_value=channels_mean),
                                              ])

train_data = datasets.CIFAR10('./data', train=True, download=True, transform=train_transforms)
test_data  = datasets.CIFAR10('./data', train=False, download=True, transform=test_transforms)

# train dataloader
trainloader = torch.utils.data.DataLoader(train_data, **dataloader_args)

# test dataloader
testloader = torch.utils.data.DataLoader(test_data, **dataloader_args)
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:643: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   warnings.warn(
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 45177043.02it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
len(trainloader)
# Out:
# 98

# %%
# Function to unnormalize and bring back to original pixel values. Transpose is to reshape the image on x & y axes and make it ready for display
def unnormalize(img):
    for i in range(img.shape[0]):
        img[i] = (img[i]*channels_stdev[i])+channels_mean[i]
    img = img.permute(1, 2, 0)
    return img

# %%
images, labels = next(iter(trainloader))
print(f'images.size() : {images.size()}, labels.size() : {labels.size()}')
num_classes = 10
num_images  = 5
fig_name    = 'Train_Images'
lst = []
fig = plt.figure(figsize=(14,14))
for i in range(num_classes):
    idx = np.random.choice(np.where(labels[:]==i)[0], num_images)
    lst.extend(images[idx])
disp_grid = torchvision.utils.make_grid(lst, 5)
disp_grid1 = unnormalize(disp_grid)

plt.imshow(disp_grid1)
plt.axis('off')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# images.size() : torch.Size([512, 3, 32, 32]), labels.size() : torch.Size([512])
# (-0.5, 171.5, 341.5, -0.5)

# %% [markdown]
# # CIFAR10 - VAE

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Build the Models

# %%
class Encoder(nn.Module):
    """
    Creates the Encoder

    nc (int): number of channels of the input image
    ndf (int): number of feature maps for the discriminator

    This uses the special Spectral Normalization ref: https://arxiv.org/abs/1802.05957
    """
    def __init__(self, nc: int = 3, ndf: int = 16, z_dim: int = 20):
        super(Encoder, self).__init__()

        self.main = nn.Sequential(
            # input is (nc) x 32 x 32
            torch.nn.utils.spectral_norm(nn.Conv2d(nc, ndf, 4, 2, 1, bias=False)),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 16 x 16
            torch.nn.utils.spectral_norm(nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False)),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 8 x 8
            torch.nn.utils.spectral_norm(nn.Conv2d(ndf * 2, 10, 4, 2, 1, bias=False)),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (10) x 4 x 4
        )

        self.expand_fc  = nn.Conv2d(20, ndf *2, kernel_size=1)
        self.gap = nn.AdaptiveAvgPool2d(1) # 10 x 1 x 1

        self.mu = nn.Conv2d(ndf * 2, z_dim, 1, bias=False)
        self.logvar = nn.Conv2d(ndf * 2, z_dim, 1, bias=False)

    def forward(self, input, one_hot_label):
        # one_hot_label = one_hot_label.squeeze(1)
        out = self.main(input)
        out = self.gap(out)    # B x 10 x 1 x 1
        out = out.view(-1, 10) # B x 10
        out = torch.cat((out, one_hot_label), dim=1)  # B x 20
        out = out.unsqueeze(-1).unsqueeze(-1)     # B x 20 x 1 x 1
        out = self.expand_fc(out)  # B x (ndf * 2) x 1 x 1
        mu = self.mu(out)
        logvar = self.logvar(out)
        return mu, logvar

# %%
class Decoder(nn.Module):
    """
    Creates the Decoder

    nc (int): channels in the final output
    nz (int): size of the latent z vector
    ngf (int): number of feature maps for the generator
    """
    def __init__(self, nc: int = 3, ngf: int = 16, z_dim: int = 20):
        super(Decoder, self).__init__()

        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( z_dim, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d( ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, nc, 4, 2, 1, bias=False),
            nn.BatchNorm2d(nc),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.Tanh()
        )

    def forward(self, input):
        decoder_out = self.main(input)
        return decoder_out

# %%
class cifar10VAE(nn.Module):
    def __init__(self, nc: int = 3, nf: int = 8, z_dims: int = 20):
        super(cifar10VAE, self).__init__()

        self.encoder = Encoder(nc, nf, z_dims)
        self.decoder = Decoder(nc, nf * 2, z_dims)

    def reparameterize(self, mu, logvar):
        if self.training:
            std = torch.exp(0.5 * logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu

    def reparam_like_train(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)

    def forward(self, input, one_hot_label):
        mu, logvar = self.encoder(input, one_hot_label)
        z = self.reparameterize(mu, logvar)
        out = self.decoder(z)

        return out, mu, logvar

# %%
cifar10VAE = cifar10VAE(nc=3, nf=32, z_dims=1024).to(device)

# %%
input = torch.randn(1, 3, 32, 32).to(device)
one_hot_label = torch.randn(1, 10).to(device)
[x.shape for x in cifar10VAE(input, one_hot_label)]
# Out:
# [torch.Size([1, 3, 32, 32]),
#  torch.Size([1, 1024, 1, 1]),
#  torch.Size([1, 1024, 1, 1])]

# %%
def vae_gaussian_kl_loss(mu, logvar):
    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp(), dim=1)

    return KLD.mean()

def reconstruction_loss(x_reconstructed, x):
    return torch.sum(F.mse_loss(x_reconstructed, x, reduction='none'), dim=(1, 2, 3)).mean()

def kl_divergence_loss(mean, logvar):
        return ((mean**2 + logvar.exp() - 1 - logvar) / 2).mean()

def loss_function(y_pred, y_true):

    recon_x, mu, logvar = y_pred

    recon_loss = reconstruction_loss(recon_x, y_true)

    kld_loss = vae_gaussian_kl_loss(mu, logvar)

    return recon_loss + kld_loss

# %%
input = torch.randn(32, 3, 32, 32).to(device)
one_hot_label = torch.randn(32, 10).to(device)
y_true = torch.randn(32, 3, 32, 32).to(device)
output = cifar10VAE(input, one_hot_label)
loss = loss_function(output, y_true)
loss
# Out:
# tensor(3686.6921, device='cuda:0', grad_fn=<AddBackward0>)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ## Train the Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
optimizer = optim.Adam(cifar10VAE.parameters(), lr=1e-4)

# %%
def train_epoch(model, optimizer):
    model.train()

    model = model.to(device)

    train_loss = 0

    for batch_idx, (data, label) in enumerate(trainloader):
        data = data.to(device)
        label_one_hot = F.one_hot(label, 10).float().cuda()

        optimizer.zero_grad() # zero out the gradients

        output = model(data, label_one_hot ) # forward pass

        loss = loss_function(output, data) # compute the loss

        loss.backward() # backprop the loss

        train_loss += loss.item()

        optimizer.step() # update the optimizer

        if batch_idx % 50 == 0:
            print(f'Loss={loss.item() :0.4f} Batch={batch_idx}')

    epoch_loss = train_loss / len(trainloader)

    print(f'Train set: Average loss for epoch : {epoch_loss: .4f} len(train_loader) : {len(trainloader)}')

    return epoch_loss

# %%
NUM_EPOCHS = 100
out_images = Path('vae_output')
out_images.mkdir(parents=True, exist_ok=True)
for epoch in tqdm(range(1, NUM_EPOCHS + 1)):
    avg_loss = train_epoch(cifar10VAE, optimizer)
    if epoch % 20 == 0 or epoch == NUM_EPOCHS:
        print(f'=> Epoch: {epoch}\tAverage Loss: {avg_loss:.4f}\n')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Loss=2924.1753 Batch=0
# Loss=2514.5698 Batch=50
# Train set: Average loss for epoch :  2472.6419 len(train_loader) : 98
# Loss=2197.8223 Batch=0
# Loss=2041.1355 Batch=50
# Train set: Average loss for epoch :  2110.7965 len(train_loader) : 98
# Loss=2009.8218 Batch=0
# Loss=1939.3394 Batch=50
# Train set: Average loss for epoch :  1986.2453 len(train_loader) : 98
# Loss=1958.4771 Batch=0
# Loss=1992.2501 Batch=50
# Train set: Average loss for epoch :  1947.8695 len(train_loader) : 98
# Loss=1931.3112 Batch=0
# Loss=1934.4310 Batch=50
# Train set: Average loss for epoch :  1921.8948 len(train_loader) : 98
# Loss=1909.7942 Batch=0
# Loss=1882.4243 Batch=50
# Train set: Average loss for epoch :  1905.3034 len(train_loader) : 98
# Loss=1867.9108 Batch=0
# Loss=1880.8197 Batch=50
# Train set: Average loss for epoch :  1886.8074 len(train_loader) : 98
# Loss=1854.5419 Batch=0
# Loss=1837.3732 Batch=50
# Train set: Average loss for epoch :  1868.8267 len(train_loader) : 98
# Loss=1915.1499 Batch=0
# Loss=1811.9348 Batch=50
# Train set: Average loss for epoch :  1862.1952 len(train_loader) : 98
# Loss=1855.3594 Batch=0
# Loss=1837.9844 Batch=50
# Train set: Average loss for epoch :  1855.1861 len(train_loader) : 98
# Loss=1797.1429 Batch=0
# Loss=1863.5282 Batch=50
# Train set: Average loss for epoch :  1849.6549 len(train_loader) : 98
# Loss=1834.0569 Batch=0
# Loss=1875.6201 Batch=50
# Train set: Average loss for epoch :  1846.4519 len(train_loader) : 98
# Loss=1852.4269 Batch=0
# Loss=1859.0963 Batch=50
# Train set: Average loss for epoch :  1841.4493 len(train_loader) : 98
# Loss=1860.4865 Batch=0
# Loss=1860.2334 Batch=50
# Train set: Average loss for epoch :  1839.3975 len(train_loader) : 98
# Loss=1779.0880 Batch=0
# Loss=1811.9792 Batch=50
# Train set: Average loss for epoch :  1832.9254 len(train_loader) : 98
# Loss=1823.7397 Batch=0
# Loss=1835.2955 Batch=50
# Train set: Average loss for epoch :  1830.2733 len(train_loader) : 98
# Loss=1794.5166 Batch=0
# Loss=1782.7617 Batch=50
# Train set: Average loss for epoch :  1828.6177 len(train_loader) : 98
# Loss=1795.7729 Batch=0
# Loss=1761.2408 Batch=50
# Train set: Average loss for epoch :  1825.5457 len(train_loader) : 98
# Loss=1833.8007 Batch=0
# Loss=1831.4253 Batch=50
# Train set: Average loss for epoch :  1822.2800 len(train_loader) : 98
# Loss=1855.6320 Batch=0
# Loss=1899.9468 Batch=50
# Train set: Average loss for epoch :  1820.8039 len(train_loader) : 98
# => Epoch: 20	Average Loss: 1820.8039
#
# Loss=1796.7708 Batch=0
# Loss=1838.9644 Batch=50
# Train set: Average loss for epoch :  1820.3769 len(train_loader) : 98
# Loss=1735.0382 Batch=0
# Loss=1766.1998 Batch=50
# Train set: Average loss for epoch :  1814.7158 len(train_loader) : 98
# Loss=1877.4847 Batch=0
# Loss=1809.2832 Batch=50
# Train set: Average loss for epoch :  1815.0227 len(train_loader) : 98
# Loss=1739.8473 Batch=0
# Loss=1841.5417 Batch=50
# Train set: Average loss for epoch :  1810.5637 len(train_loader) : 98
# Loss=1811.4729 Batch=0
# Loss=1797.0072 Batch=50
# Train set: Average loss for epoch :  1808.2340 len(train_loader) : 98
# Loss=1862.3752 Batch=0
# Loss=1763.3167 Batch=50
# Train set: Average loss for epoch :  1806.0217 len(train_loader) : 98
# Loss=1811.8248 Batch=0
# Loss=1833.1893 Batch=50
# Train set: Average loss for epoch :  1804.9810 len(train_loader) : 98
# Loss=1767.0156 Batch=0
# Loss=1765.0743 Batch=50
# Train set: Average loss for epoch :  1799.4127 len(train_loader) : 98
# Loss=1836.6343 Batch=0
# Loss=1768.8962 Batch=50
# Train set: Average loss for epoch :  1799.1030 len(train_loader) : 98
# Loss=1783.4956 Batch=0
# Loss=1777.5040 Batch=50
# Train set: Average loss for epoch :  1797.1625 len(train_loader) : 98
# Loss=1835.5099 Batch=0
# Loss=1758.6802 Batch=50
# Train set: Average loss for epoch :  1795.0527 len(train_loader) : 98
# Loss=1824.5142 Batch=0
# Loss=1820.6090 Batch=50
# Train set: Average loss for epoch :  1794.0497 len(train_loader) : 98
# Loss=1864.6222 Batch=0
# Loss=1817.1124 Batch=50
# Train set: Average loss for epoch :  1792.3316 len(train_loader) : 98
# Loss=1837.2648 Batch=0
# Loss=1725.4611 Batch=50
# Train set: Average loss for epoch :  1793.3587 len(train_loader) : 98
# Loss=1713.7382 Batch=0
# Loss=1765.7898 Batch=50
# Train set: Average loss for epoch :  1791.7582 len(train_loader) : 98
# Loss=1861.7336 Batch=0
# Loss=1813.1045 Batch=50
# Train set: Average loss for epoch :  1791.2080 len(train_loader) : 98
# Loss=1718.7629 Batch=0
# Loss=1773.5636 Batch=50
# Train set: Average loss for epoch :  1788.8148 len(train_loader) : 98
# Loss=1824.2284 Batch=0
# Loss=1729.3071 Batch=50
# Train set: Average loss for epoch :  1787.7966 len(train_loader) : 98
# Loss=1760.5853 Batch=0
# Loss=1753.0958 Batch=50
# Train set: Average loss for epoch :  1786.9573 len(train_loader) : 98
# Loss=1842.6093 Batch=0
# Loss=1777.0857 Batch=50
# Train set: Average loss for epoch :  1786.5994 len(train_loader) : 98
# => Epoch: 40	Average Loss: 1786.5994
#
# Loss=1846.1949 Batch=0
# Loss=1775.4226 Batch=50
# Train set: Average loss for epoch :  1784.5881 len(train_loader) : 98
# Loss=1868.7183 Batch=0
# Loss=1752.8702 Batch=50
# Train set: Average loss for epoch :  1784.6203 len(train_loader) : 98
# Loss=1787.9534 Batch=0
# Loss=1752.9817 Batch=50
# Train set: Average loss for epoch :  1784.8254 len(train_loader) : 98
# Loss=1826.6785 Batch=0
# Loss=1811.2983 Batch=50
# Train set: Average loss for epoch :  1783.1503 len(train_loader) : 98
# Loss=1803.1833 Batch=0
# Loss=1804.0269 Batch=50
# Train set: Average loss for epoch :  1780.9953 len(train_loader) : 98
# Loss=1765.8510 Batch=0
# Loss=1753.9821 Batch=50
# Train set: Average loss for epoch :  1778.5680 len(train_loader) : 98
# Loss=1760.7732 Batch=0
# Loss=1735.4071 Batch=50
# Train set: Average loss for epoch :  1777.8230 len(train_loader) : 98
# Loss=1804.4933 Batch=0
# Loss=1728.3308 Batch=50
# Train set: Average loss for epoch :  1776.3031 len(train_loader) : 98
# Loss=1761.5648 Batch=0
# Loss=1727.3629 Batch=50
# Train set: Average loss for epoch :  1778.5884 len(train_loader) : 98
# Loss=1755.5858 Batch=0
# Loss=1833.9678 Batch=50
# Train set: Average loss for epoch :  1774.3184 len(train_loader) : 98
# Loss=1800.7054 Batch=0
# Loss=1783.4595 Batch=50
# Train set: Average loss for epoch :  1772.9884 len(train_loader) : 98
# Loss=1770.0427 Batch=0
# Loss=1832.2112 Batch=50
# Train set: Average loss for epoch :  1772.0630 len(train_loader) : 98
# Loss=1797.6775 Batch=0
# Loss=1763.5798 Batch=50
# Train set: Average loss for epoch :  1770.0134 len(train_loader) : 98
# Loss=1837.6344 Batch=0
# Loss=1862.1111 Batch=50
# Train set: Average loss for epoch :  1772.3212 len(train_loader) : 98
# Loss=1741.9011 Batch=0
# Loss=1830.4546 Batch=50
# Train set: Average loss for epoch :  1770.7899 len(train_loader) : 98
# Loss=1729.5988 Batch=0
# Loss=1791.1650 Batch=50
# Train set: Average loss for epoch :  1769.2544 len(train_loader) : 98
# Loss=1788.9924 Batch=0
# Loss=1725.0768 Batch=50
# Train set: Average loss for epoch :  1768.3991 len(train_loader) : 98
# Loss=1734.8090 Batch=0
# Loss=1815.3688 Batch=50
# Train set: Average loss for epoch :  1768.8230 len(train_loader) : 98
# Loss=1779.6836 Batch=0
# Loss=1733.8273 Batch=50
# Train set: Average loss for epoch :  1767.4720 len(train_loader) : 98
# Loss=1811.2028 Batch=0
# Loss=1816.0449 Batch=50
# Train set: Average loss for epoch :  1766.1059 len(train_loader) : 98
# => Epoch: 60	Average Loss: 1766.1059
#
# Loss=1792.3323 Batch=0
# Loss=1777.1808 Batch=50
# Train set: Average loss for epoch :  1766.8513 len(train_loader) : 98
# Loss=1840.1646 Batch=0
# Loss=1825.0712 Batch=50
# Train set: Average loss for epoch :  1766.2259 len(train_loader) : 98
# Loss=1772.1604 Batch=0
# Loss=1786.7789 Batch=50
# Train set: Average loss for epoch :  1768.1012 len(train_loader) : 98
# Loss=1783.1469 Batch=0
# Loss=1741.8015 Batch=50
# Train set: Average loss for epoch :  1764.7661 len(train_loader) : 98
# Loss=1744.4344 Batch=0
# Loss=1802.1788 Batch=50
# Train set: Average loss for epoch :  1765.2544 len(train_loader) : 98
# Loss=1736.9857 Batch=0
# Loss=1799.3416 Batch=50
# Train set: Average loss for epoch :  1763.9966 len(train_loader) : 98
# Loss=1710.7249 Batch=0
# Loss=1778.2175 Batch=50
# Train set: Average loss for epoch :  1763.1699 len(train_loader) : 98
# Loss=1764.6447 Batch=0
# Loss=1735.8473 Batch=50
# Train set: Average loss for epoch :  1764.0891 len(train_loader) : 98
# Loss=1778.9913 Batch=0
# Loss=1810.8325 Batch=50
# Train set: Average loss for epoch :  1765.8767 len(train_loader) : 98
# Loss=1753.1180 Batch=0
# Loss=1736.4952 Batch=50
# Train set: Average loss for epoch :  1764.8104 len(train_loader) : 98
# Loss=1771.0657 Batch=0
# Loss=1772.0074 Batch=50
# Train set: Average loss for epoch :  1763.9850 len(train_loader) : 98
# Loss=1833.4124 Batch=0
# Loss=1757.5170 Batch=50
# Train set: Average loss for epoch :  1761.7468 len(train_loader) : 98
# Loss=1721.0620 Batch=0
# Loss=1762.1631 Batch=50
# Train set: Average loss for epoch :  1762.0790 len(train_loader) : 98
# Loss=1805.9933 Batch=0
# Loss=1755.0242 Batch=50
# Train set: Average loss for epoch :  1762.0660 len(train_loader) : 98
# Loss=1750.9829 Batch=0
# Loss=1790.6487 Batch=50
# Train set: Average loss for epoch :  1761.2279 len(train_loader) : 98
# Loss=1807.7015 Batch=0
# Loss=1767.6592 Batch=50
# Train set: Average loss for epoch :  1759.1823 len(train_loader) : 98
# Loss=1774.0521 Batch=0
# Loss=1764.1663 Batch=50
# Train set: Average loss for epoch :  1760.2409 len(train_loader) : 98
# Loss=1763.2534 Batch=0
# Loss=1759.4126 Batch=50
# Train set: Average loss for epoch :  1762.5028 len(train_loader) : 98
# Loss=1757.0776 Batch=0
# Loss=1762.2599 Batch=50
# Train set: Average loss for epoch :  1759.4765 len(train_loader) : 98
# Loss=1703.5897 Batch=0
# Loss=1745.4093 Batch=50
# Train set: Average loss for epoch :  1758.7374 len(train_loader) : 98
# => Epoch: 80	Average Loss: 1758.7374
#
# Loss=1805.7024 Batch=0
# Loss=1732.2195 Batch=50
# Train set: Average loss for epoch :  1760.8592 len(train_loader) : 98
# Loss=1749.0840 Batch=0
# Loss=1807.6271 Batch=50
# Train set: Average loss for epoch :  1761.9187 len(train_loader) : 98
# Loss=1812.5681 Batch=0
# Loss=1782.5975 Batch=50
# Train set: Average loss for epoch :  1760.6313 len(train_loader) : 98
# Loss=1646.5938 Batch=0
# Loss=1730.8004 Batch=50
# Train set: Average loss for epoch :  1761.4305 len(train_loader) : 98
# Loss=1765.5781 Batch=0
# Loss=1771.3395 Batch=50
# Train set: Average loss for epoch :  1758.1998 len(train_loader) : 98
# Loss=1737.9067 Batch=0
# Loss=1779.4604 Batch=50
# Train set: Average loss for epoch :  1761.5764 len(train_loader) : 98
# Loss=1808.0697 Batch=0
# Loss=1714.0769 Batch=50
# Train set: Average loss for epoch :  1759.0407 len(train_loader) : 98
# Loss=1743.7078 Batch=0
# Loss=1800.2041 Batch=50
# Train set: Average loss for epoch :  1757.1548 len(train_loader) : 98
# Loss=1745.3439 Batch=0
# Loss=1778.8325 Batch=50
# Train set: Average loss for epoch :  1757.8068 len(train_loader) : 98
# Loss=1808.1591 Batch=0
# Loss=1710.4011 Batch=50
# Train set: Average loss for epoch :  1759.7714 len(train_loader) : 98
# Loss=1683.3591 Batch=0
# Loss=1832.9677 Batch=50
# Train set: Average loss for epoch :  1755.7879 len(train_loader) : 98
# Loss=1756.5214 Batch=0
# Loss=1683.0759 Batch=50
# Train set: Average loss for epoch :  1758.8704 len(train_loader) : 98
# Loss=1762.3033 Batch=0
# Loss=1733.2820 Batch=50
# Train set: Average loss for epoch :  1759.4189 len(train_loader) : 98
# Loss=1736.8363 Batch=0
# Loss=1746.6552 Batch=50
# Train set: Average loss for epoch :  1757.4450 len(train_loader) : 98
# Loss=1712.7567 Batch=0
# Loss=1751.3160 Batch=50
# Train set: Average loss for epoch :  1758.5340 len(train_loader) : 98
# Loss=1780.9385 Batch=0
# Loss=1830.6188 Batch=50
# Train set: Average loss for epoch :  1757.9958 len(train_loader) : 98
# Loss=1846.6998 Batch=0
# Loss=1728.7740 Batch=50
# Train set: Average loss for epoch :  1755.7436 len(train_loader) : 98
# Loss=1770.8301 Batch=0
# Loss=1797.0219 Batch=50
# Train set: Average loss for epoch :  1756.8382 len(train_loader) : 98
# Loss=1743.1591 Batch=0
# Loss=1760.8538 Batch=50
# Train set: Average loss for epoch :  1756.3445 len(train_loader) : 98
# Loss=1814.3380 Batch=0
# Loss=1711.7079 Batch=50
# Train set: Average loss for epoch :  1756.2886 len(train_loader) : 98
# => Epoch: 100	Average Loss: 1756.2886

# %% [markdown]
# Let's try to see what the model outputs if we provide it with some random z vector

# %%
val_loader = torch.utils.data.DataLoader(test_data, batch_size=32)
def validate(model):
    model.eval()
    with torch.no_grad():
        i = 0
        for data, label in val_loader:
            i += 1
            if i > 0:
                break
        print(f'Correct  label : {label.tolist()}')
        data = data.float().cuda()
        label_one_hot_val = F.one_hot(label, 10).float().cuda()
        output = model(data, label_one_hot_val)
        save_image(data, '/content/vae_output/data_32' + '.png')
        save_image(output[0].view(32, 3, 32, 32), '/content/vae_output/sample_32_correct' + '.png')

        for lab in label:
            if lab == 9:
                lab -= 1
            else:
                lab += 1

        print(f'Modified label : {label.tolist()}')
        label_one_hot_val_wrong = F.one_hot(label, 10).float().cuda()
        output_wrong = model(data, label_one_hot_val_wrong)
        save_image(output_wrong[0].view(32, 3, 32, 32), '/content/vae_output/sample_32_wrong' + '.png')

        return data, output[0], output_wrong[0]

# %%
data, out, out_w = validate(cifar10VAE)
# Out:
# Correct  label : [3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9, 5, 2, 4, 0, 9, 6, 6, 5]
# Modified label : [4, 9, 9, 1, 7, 7, 2, 7, 4, 2, 1, 8, 6, 8, 8, 9, 6, 8, 9, 7, 8, 1, 5, 8, 6, 3, 5, 1, 8, 7, 7, 6]

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor
unorm = UnNormalize(mean=channels_mean, std=channels_stdev)

# %%
def norm_ip(img, min, max):
    img.clamp_(min=min, max=max)
    img.add_(-min).div_(max - min + 1e-5)

def norm_tensor(t):
    norm_ip(t, float(t.min()), float(t.max()))

# %% [markdown]
# Display output, when correct labels were fed

# %%
fig = plt.figure(figsize=(10, 10))
for idx, image in enumerate(out[:32]):
    plt.subplot(8, 8, idx+1)
    image.squeeze_(0)
    # image = unorm(image)
    norm_tensor(image)
    plt.imshow(image.permute(1, 2, 0).cpu())
    plt.axis('off')
    plt.grid('off')
plt.tight_layout()
fig.canvas.draw()
correct = np.array(fig.canvas.renderer.buffer_rgba())

# %% [markdown]
# Display output, when in-correct labels were fed

# %%
fig = plt.figure(figsize=(10, 10))
for idx, image in enumerate(out_w[:32]):
    plt.subplot(8, 8, idx+1)
    image.squeeze_(0)
    norm_tensor(image)
    # image = unorm(image)
    plt.imshow(image.permute(1, 2, 0).cpu())
    plt.axis('off')
    plt.grid('off')
plt.tight_layout()
fig.canvas.draw()
wrong = np.array(fig.canvas.renderer.buffer_rgba())

# %%
fig = plt.figure(figsize=(10, 10))
for idx, image in enumerate(data[:32]):
    plt.subplot(8, 8, idx+1)
    image.squeeze_(0)
    # image = unorm(image)
    norm_tensor(image)
    plt.imshow(image.permute(1, 2, 0).cpu())
    plt.axis('off')
    plt.grid('off')
plt.tight_layout()
fig.canvas.draw()
real = np.array(fig.canvas.renderer.buffer_rgba())

# %%
fig = plt.figure(figsize=(15, 10))

plt.subplot(1, 3, 1)
plt.imshow(real)
plt.title('Real')
plt.grid('off')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(correct)
plt.title('Correct Label Fed')
plt.grid('off')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(wrong)
plt.title('Incorrect Label Fed')
plt.grid('off')
plt.axis('off')

plt.show()
